# %%
"""
CW + HW

Mid exam = 7
Viva = 5
Assignment = 5
Attendance = 3


np.shape  -> (row,column) for a 2D array
normal indexing

slicing [start:end:step]

print(x[1,2]) -> means 3rd element of 2nd list 
print(x[:,0]) -> gives all the 1st column 
2D array is printed in a row and column style


np.zeros((row,column)) gives a 2D array of all zeros

np.ones() gives all 1

np.sum(x)  all ememnts of x added
np.sum(x,axis=0)   axis =0 means added column wise
np.sum(x,axis=1)
np.prod(x)



np.linspace(0,100,51) ->giving  51 values from 0 to 100 equally spaced 
"""


import numpy as np

x = np.array([[1,2,3],[4,5,6]])

print(print(x[:,0]))
# Out:
# [1 4]
# None
